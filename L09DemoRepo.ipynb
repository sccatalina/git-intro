# %% [markdown]
# # Import Packages

# %%
from IPython.display import Image

# %% [markdown]
# # Create Repo

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/01CreateRepo.png')

# %% [markdown]
# # Clone Repo in GitHub Desktop

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/02CloneRepo.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/03CloneRepo2.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/04CloneRepo3.png')

# %% [markdown]
# # Using your Repo

# %% [markdown]
# ## Main branch

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/05MasterBranch.png')

# %% [markdown]
# ## Adding and Modifying files in local folder

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/06newFile.txt.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/07READMEChanges.png')

# %% [markdown]
# ## Pushing original changes to the main branch

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/11pushOrigin.png')

# %% [markdown]
# ## Creating a Branch in GitHub Desktop

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/08newBranch1.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/09newBranch2.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/10newBranch3.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/08RepoHistory.png')

# %% [markdown]
# ## Commiting changes to README to dev branch

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/12CommitToDev.png')

# %% [markdown]
# ## Creating a pull request from dev branch

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/13devPullRequest.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/14PullRequest.png')

# %% [markdown]
# ## Merge pull request without conflicts

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/15PullRequest.png')

# %% [markdown]
# ## Resoliving conflict in github.com

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/16ConflictPullRequest.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/17ResolveConflicts.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/18ResolveConflicts.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/19ResolveConflicts.png')

# %% [markdown]
# ## Merging dev branch into main

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/20CommitMerge.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/21MergePullRequest.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/DS0107-BigData/L09/22ConfirmMerge.png')
